# %% [markdown]
# <a href="https://colab.research.google.com/github/Tanmay123i/Advanced-statistics-simulation/blob/main/Visualizing_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pandas.core import indexing
import pandas as pd
import gspread


worksheet = gc.open('dataset5').sheet1
rows = worksheet.get_all_values()


df = pd.DataFrame.from_records(rows[1:], columns=rows[0])

# %%
import gspread
import pandas as pd
from google.colab import auth
auth.authenticate_user()
from google.auth import default

creds, _ = default()
gc = gspread.authorize(creds)

# %%
df
# Out:
#        CurrentRatio       QuickRatio      CashRatio            P/E  \
# 0      0.3310960922      0.370957488   -1.454801411    1.357958653
# 1      0.3279533474    0.07588734314  -0.5321936281   0.4711975047
# 2      0.6237925491     0.5039861621  -0.6470112657  -0.2072638376
# 3    0.003123346233  -0.005636527155  -0.8159352718    1.204640776
# 4     -0.9110284267    -0.3580497755   0.4647539984   0.4110860394
# ..              ...              ...            ...            ...
# 995  0.005076692556    0.03177096663   -1.115504596    1.584171115
# 996     1.338833171    0.09091966015   0.9407078495   -2.300527453
# 997     1.357036129     0.9683407777   -1.118417498  -0.6732086003
# 998     1.404150372      1.067058995   -1.217079346  -0.7114733161
# 999   -0.5544455819    -0.4242247786    0.547627456   0.1870746718
#
#      EarningsYield           ROCE           CASA      Sector P/E    Status  \
# 0    -0.6968541581    0.3138135511   -1.115697961   -2.213527285  Accepted
# ...

# %%
df1=df[["CashRatio","P/E","EarningsYield"]]

# %%
df1
# Out:
#          CashRatio            P/E  EarningsYield
# 0     -1.454801411    1.357958653  -0.6968541581
# 1    -0.5321936281   0.4711975047  -0.6530427821
# 2    -0.6470112657  -0.2072638376  -0.6111276864
# 3    -0.8159352718    1.204640776  -0.3837182201
# 4     0.4647539984   0.4110860394    1.162236039
# ..             ...            ...            ...
# 995   -1.115504596    1.584171115  -0.4748461892
# 996   0.9407078495   -2.300527453   -1.530910288
# 997   -1.118417498  -0.6732086003   -1.363266513
# 998   -1.217079346  -0.7114733161   -1.353736899
# 999    0.547627456   0.1870746718    0.561348662
#
# [1000 rows x 3 columns]

# %%
import pandas as pd
import numpy as np

# %%
correlation_table = df1.astype(float).corr()

print(correlation_table)
# Out:
#                CashRatio       P/E  EarningsYield
# CashRatio       1.000000 -0.161169       0.520896
# P/E            -0.161169  1.000000       0.627041
# EarningsYield   0.520896  0.627041       1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(df1)
# Out:
#          CashRatio            P/E  EarningsYield
# 0     -1.454801411    1.357958653  -0.6968541581
# 1    -0.5321936281   0.4711975047  -0.6530427821
# 2    -0.6470112657  -0.2072638376  -0.6111276864
# 3    -0.8159352718    1.204640776  -0.3837182201
# 4     0.4647539984   0.4110860394    1.162236039
# ..             ...            ...            ...
# 995   -1.115504596    1.584171115  -0.4748461892
# 996   0.9407078495   -2.300527453   -1.530910288
# 997   -1.118417498  -0.6732086003   -1.363266513
# 998   -1.217079346  -0.7114733161   -1.353736899
# 999    0.547627456   0.1870746718    0.561348662
#
# [1000 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df1=df1.astype(float)
sns.pairplot(df1)
plt.show()

# %%
# Calculate mean for each column
means = df1.mean()

# Calculate standard deviation for each column
std_devs = df1.std()

# Print or display the means and standard deviations
print("Mean Values:")
print(means)
print("\nStandard Deviations:")
print(std_devs)
# Out:
# Mean Values:
# CashRatio       -0.429002
# P/E             -0.504235
# EarningsYield   -0.708805
# dtype: float64
#
# Standard Deviations:
# CashRatio        1.262749
# P/E              1.327434
# EarningsYield    1.115273
# dtype: float64
